# %% [markdown]
# # Data Science Tools in a nutshell

# %% [markdown]
# ## Objectives and introduction
# In this book I am going to identify some important tools for data science.
# For instance:
# - Popular data science languages, tools and libraries
# - Demostration of writing simple code in jupyter notebook
# - I will also show how perform simple text formats to create emphasis where they need to be.

# %% [markdown]
# ### Data Science languages, Libraries and Tools
#    #### Popular languages
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Julia
# and others.

# %% [markdown]
#    #### Popular libraries
# 1. Pandas
# 2. Numpy
# 3. Scipy
# 4. Matplotlib
# 5. Tensorflow
# and many others

# %% [markdown]
#   #### Popular libraries
# 1. SQL
# 2. Jupyter Notebook
# 3. Spark
# 4. Hadoop
# 5. Kafka
# 6. Excel
# and many others

# %% [markdown]
# __Arithmetic__
#
#
# _x = 2
# y = 2
# c = x + y
# a = c * y
# print(c)
# print(a)_
#
# De

# %%
x = 2
y = 3
z = x + y
a = x * z
print(z)
print(a)

# Out(1): 5
# Out(2): 10
# Out:
# 5
# 10

# %%
# Convert given minutes to
def to_hour(a):
    return a / 60

print(f"900 minutes equals: {int(to_hour(900))} Hours.")
# Out:
# 900 minutes equals: 15 Hours.
